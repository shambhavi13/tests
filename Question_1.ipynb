# %% [markdown]
# ### Load data

# %%
import pandas as pd
import numpy as np

na_values = ['NO CLUE', 'N/A', '0']
# the request is not a dataframe but
# TextFileReader object for iteration
requests = pd.read_csv('311_data.csv',
                       chunksize=1000000,
                       na_values=na_values,
                       low_memory=False,
                       dtype={'Incident Zip': str})

def chunk_data(requests):
    chunk_list = []  # append each chunk df here
    # Each chunk is in df format
    for chunk in requests:
        chunk_list.append(chunk)
        # concat the list into dataframe
    df_concat = pd.concat(chunk_list)

    return df_concat

def fix_zip_codes(zips):
    # Truncate everything to length 5
    zips = zips.str.slice(0, 5)

    # Set 00000 zip codes to nan
    zero_zips = zips == '00000'
    zips[zero_zips] = np.nan

    return zips


df_req = chunk_data(requests)
df_req['Incident Zip'] = fix_zip_codes(df_req['Incident Zip'])

# %% [markdown]
# # Look at data after fixing zips

# %%
df_req.rename(columns={"Agency Name": "AgencyName", "Incident Zip": "IncidentZip", "Complaint Type": "ComplaintType"})
# Rename column names for easy access
df_req.columns = df_req.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

dfObj_agency = df_req.agency.unique() #Find unique elements in the column
dfObj_agency_name = df_req.agency_name.unique() #Find unique elements in the column
dfObj_incident_zip = df_req.incident_zip.unique() #Find unique elements in the column
dfObj_complaint_type = df_req.complaint_type.unique() #Find unique elements in the column

# print unique values in these columns:
print('agency ' + str(len(dfObj_agency)))
print('agency_name ' + str(len(dfObj_agency_name)))
print('incident_zip ' + str(len(dfObj_incident_zip)))
print('complaint_type ' + str(len(dfObj_complaint_type)))


print(dfObj_incident_zip) #Review unique names for missing data or odd format
print(dfObj_agency) #Review unique names for missing data or odd format
# Out:
# agency 31
# agency_name 1933
# incident_zip 2392
# complaint_type 434
# [nan '11216' '10012' ... '11519' '01650' '45201']
# ['DOF' 'NYPD' 'DOHMH' 'DPR' 'HRA' 'TLC' 'DOT' 'DFTA' 'DSNY' 'HPD' 'DOB'
#  'DEP' 'DHS' 'DCA' 'NYCEM' 'DOE' '3-1-1' 'EDC' 'DOITT' 'DCAS' 'ACS' 'TAX'
#  'FDNY' 'DCP' 'DORIS' 'COIB' 'TAT' 'CEO' 'MOC' 'OMB' 'DVS']

# %% [markdown]
# # Perform more preprocessing remove some odd format

# %%
df_req.incident_zip.replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
df_req.complaint_type.replace(regex=True,inplace=True,to_replace=r'[^a-zA-Z ]+',value=r'')

# %%
df_req.to_csv('nyc311_filter.csv', index=False)

# %%
# Look at data format
import sys
np.set_printoptions(threshold=sys.maxsize)
print(df_req.complaint_type.unique())
print(df_req.incident_zip.unique())
# Out:
# ['SCRIE' 'Illegal Parking' 'DOF Property  Payment Issue'
#  'Indoor Air Quality' 'Dead Tree' 'Benefit Card Replacement'
#  'For Hire Vehicle Complaint' 'Sidewalk Condition'
#  'Housing  Low Income Senior' 'Traffic' 'Street Sign  Missing'
#  'DOF Property  Request Copy' 'Graffiti' 'APPLIANCE' 'DOORWINDOW'
#  'FLOORINGSTAIRS' 'GENERAL' 'Elder Abuse'
#  'Case Management Agency Complaint' 'Street Condition'
#  'Street Sign  Dangling' 'Food Establishment' 'DOF Property  Owner Issue'
#  'DOF Parking  Request Copy' 'Noise  Vehicle' 'Cranes and Derricks'
#  'Electrical' 'Scaffold Safety' 'DOF Parking  Payment Issue'
#  'Request Large Bulky Item Collection' 'Water System' 'HEATHOT WATER'
#  'HPD Literature Request' 'RootSewerSidewalk Condition'
#  'Illegal Tree Damage' 'Overgrown TreeBranches' 'Asbestos'
#  'DHS Advantage  Tenant' 'DHS Advantage LandlordBroker' 'Smoking'
#  'Blocked Driveway' 'Consumer Complaint' 'Tattooing' 'Taxi Complaint'
#  'Noise  Residential' 'Noise  StreetSidewalk' 'Maintenance or Facility'
#  'DCA  DOH New License Application Request' 'PAINT  PLASTER' 'PLUMBING'
#  'Derelict Vehicles' 'Other Enforcement' 'PAINTPLASTER'
#  'Missed Collection All Materials' 'Sanitation Condition'
#  'SweepingMissedInadequate' 'Animal Abuse' 'Violation of Park Rules'
#  'ELECTRIC' 'Rodent' 'UNSANITARY CONDITION' 'Dirty Conditions'
#  'Derelict Vehicle' 'DOF Property  Reduction Issue' 'AdoptABasket'
#  'CONSTRUCTION' 'Plumbing' 'GENERAL CONSTRUCTION' 'WATER LEAK'
#  'Highway Condition' 'Hazardous Materials' 'Noise' 'Air Quality'
#  'Recycling Enforcement' 'Damaged Tree' 'Sewer' 'HEATING' 'Construction'
#  'Street Light Condition' 'Electronics Waste' 'Curb Condition'
#  'Litter Basket  Request' 'BuildingUse' 'Homeless Encampment'
#  'Broken Muni Meter' 'Traffic Signal Condition' 'New Tree Request'
#  'NONCONST' 'DPR Internal' 'Vending' 'Lead' 'Noise  Park'
#  'Water Conservation' 'Water Quality' 'Noise  Commercial'
#  'Bridge Condition' 'Highway Sign  Damaged' 'Overflowing Litter Baskets'
#  'Derelict Bicycle' 'DOF Parking  Request Status' 'Mold'
#  'NonEmergency Police Matter' 'Animal in a Park' 'BikeRollerSkate Chronic'
#  'Food Poisoning' 'Elevator' 'General ConstructionPlumbing'
#  'OEM Literature Request' 'Vacant Lot' 'Panhandling' 'Safety'
#  'School Maintenance' 'Disorderly Youth' 'Drinking' 'Ferry Complaint'
#  'Highway Sign  Dangling' 'Broken Parking Meter'
#  'Unsanitary Animal Pvt Property' 'Urinating in Public' 'Window Guard'
#  'Ferry Inquiry' 'Taxi Compliment' 'Animal Facility  No Permit'
#  'BESTSite Safety' 'Boilers' 'Investigations and Discipline IAD'
#  'Miscellaneous Categories' 'DOF Parking  Tax Exemption'
#  'Special Projects Inspection Team SPIT' 'Bus Stop Shelter Complaint'
#  'Bus Stop Shelter Placement' 'Illegal Animal Kept as Pet'
#  'Street Sign  Damaged' 'City Vehicle Placard Complaint' 'Home Repair'
#  'Housing Options' 'Unleashed Dog' 'Utility Program' 'Weatherization'
#  'Home Delivered Meal Complaint' 'DOF Parking  DMV Clearance'
#  'DHS Advantage  Third Party' 'Alzheimers Care' 'Noise  Helicopter'
#  'HEAP Assistance' 'Drinking Water' 'Home Delivered Meal  Missed Delivery'
#  'DOF Property  City Rebate' 'SweepingInadequate' 'Industrial Waste'
#  'Pet Shop' 'DOF Property  Update Account' 'Posting Advertisement'
#  'Public Payphone Complaint' 'DeadDying Tree'
#  'Unsanitary Pigeon Condition' 'SweepingMissed' 'Taxi Report'
#  'Ferry Permit' 'Senior Center Complaint' 'Home Care Provider Complaint'
#  'Drug Activity' 'Special Natural Area District SNAD'
#  'DOF Property  Property Value' 'Harboring BeesWasps'
#  'Discipline and Suspension' 'Indoor Sewage' 'Found Property' 'Plant'
#  'DHS Income Savings Requirement' 'Illegal Animal Sold' 'SAFETY'
#  'Noise  House of Worship' 'Health' 'Emergency Response Team ERT'
#  'Municipal Parking Facility' 'Homeless Person Assistance'
#  'TeachingLearningInstruction' 'Parent Leadership' 'Illegal Fireworks'
#  'NonResidential Heat' 'BeachPoolSauna Complaint'
#  'Bereavement Support Group' 'Standing Water' 'Bike Rack Condition'
#  'Registration and Transfers' 'Unsanitary Animal Facility'
#  'Highway Sign  Missing' 'ELEVATOR' 'Squeegee' 'Question' 'Parking Card'
#  'ATF' 'Public Toilet' 'OUTSIDE BUILDING' 'Stalled Sites' 'NORC Complaint'
#  'Advocate  Other' 'Legal Services Provider Complaint'
#  'Request Xmas Tree Collection' 'Overflowing Recycling Baskets'
#  'Transportation Provider Complaint' 'XRay MachineEquipment' 'FCST'
#  'DOF Property  RPIE Issue' 'For Hire Vehicle Report' 'Calorie Labeling'
#  'Poison Ivy' 'Snow' 'SRDE' 'Radioactive Material' 'Lifeguard'
#  'Summer Camp' 'Day Care' 'DRIE' 'Portable Toilet' 'Trans Fat'
#  'No Child Left Behind' 'Forms' 'Electronics Waste Appointment'
#  'Bottled Water' 'Noise Survey' 'Collection Truck Noise' 'Lost Property'
#  'Building Condition' 'Comments' 'Forensic Engineering' 'Tunnel Condition'
#  'LinkNYC' 'Homebound Evacuation ' 'AdvocatePersonal Exemptions'
#  'Interior Demo' 'Research Questions' 'FATF' 'DEP Street Condition'
#  'Eviction' 'DOR Literature Request' 'Taxpayer Advocate Inquiry'
#  'Unlicensed Dog' 'AdvocateProp RefundsCredits' 'Mosquitoes'
#  'Standpipe  Mechanical' 'DOF Literature Request' 'Cooling Tower' 'FHE'
#  'DOF Parking  Address Update' 'Hazardous Material' 'Abandoned Vehicle'
#  'AnimalAbuse' 'Borough Office' 'Construction Safety Enforcement'
#  'Special Operations' 'SNW' 'Building Marshals office' 'Tanning'
#  'Water Maintenance' 'STRUCTURAL' 'Advocate  RPIE' 'VACANT APARTMENT'
#  'AGENCY' 'Green Taxi Report' 'Sustainability Enforcement'
#  'Green Taxi Complaint' 'AdvocateProperty Value' 'Foam Ban Enforcement'
#  'AdvocateCoopCondo Abatement' 'Advocate  Lien' 'Executive Inspections'
#  'Mobile Food Vendor' 'AdvocateSCRIEDRIE' 'Advocate  Levy'
#  'Injured Wildlife' 'Illegal Animal  SoldKept' 'Missed Collection'
#  'DEP Highway Condition' 'Single Occupancy Bathroom'
#  'AdvocateProp Class Incorrect' 'AdvocateBusiness Tax'
#  'AdvocateCommercial Exemptions' 'Facades' 'DEP Sidewalk Condition'
#  'Unsanitary Condition' 'Dept of Investigations' 'General Question'
#  'Select Message Type' 'Quality of Life' 'FHV Licensee Complaint'
#  'Dispatched Taxi Complaint' 'AdvocateForeclosure' 'sleep ' ''
#  'Misc Commentsdeclare q ' 'caecaecaecae' 'Misc Commentsping n  '
#  'fileetcpasswd' 'select loadfileh' 'Misc Commentsselectfrom' 'hcvngji'
#  'Misc Commentsdeclare q' 'Misc Comments' 'windowswinini'
#  'Misc Commentssleepto' 'Misc Commentsping c  ' 'filecwindowswinini'
#  'dmognlOgnlContextDE' 'Misc Comments and ' 'Misc Comments and select'
#  'Misc Comments  BCCaglxzf' 'Misc Commentsselectfro'
#  'Misc Commentsevalcompil' 'httpgorzhiushzrj' 'Misc Commentsecho xjd'
#  'xmlparser vDOCTYPE' 'MSOTHER' 'Misc Commentsping n '
#  'Misc Commentsnslookup' 'odb xmlnsxihttp' 'aabc' '    ' 'objectClass'
#  'etcpasswd' 'Misc Commentsdeclare q v' 'Misc Commentsecho pwexz'
#  'cwindowswinini Misc Co' 'nslookup qcname nneyfcxgy' 'WEBINFwebxml'
#  'goiissobjectClass' 'kawnlcgv' 'WEBINFwebxmlx' 'Misc Commentsfunction'
#  'Misc Commentssleep' 'Misc Comments or ' 'eeceeceec'
#  'select extractvaluexmltyp' 'Misc Commentsselect ex' 'Misc Commentstvquo'
#  'cwindowswinini' 'idexfmrbobjectClass' 'EAEDXInjecti' '   binsleep '
#  'validateformphp' 'Misc Commentsdtpqquo' 'Misc Commentsselect loa'
#  'Misc Commentswaitfor d' 'qfixlixaf' 'caecaeWEBINFwebxml'
#  'caeWEBINFwebxml' 'evalcompilefor x in rang' 'ywygis' 'eefeefeef'
#  'fetcfpasswd' 'caecaecaeWEBIN' 'dyrgvhgegsypoqaxbms'
#  'Misc Comments waitfor del' 'Misc Commentswaitfor del'
#  'Misc Commentsecho yvfc' 'Misc Commentseowljujfh'
#  'Misc Commentsnslookup q' 'Misc Commentsamp' 'Misc Commentsping '
#  'Misc Commentsecho ' 'Misc Commentsowrxb' 'bcdesiggplt'
#  'Employee Behavior' 'DSNY Spillage' 'General' 'Appliance'
#  'Taxi Licensee Complaint' 'vlv xmlnshttp' 'Misc Comments  BCCbl'
#  'Internal Code' 'Outside Building' 'Water Leak' 'Electric'
#  'Fire Alarm  Modification' 'Fire Alarm  New System' 'Open Flame Permit'
#  'Rangehood' 'Public Assembly' 'Fire Alarm  Reinspection'
#  'Hazmat StorageUse' 'Sprinkler  Mechanical' 'Public Assembly  Temporary'
#  'Gas Station Discharge Lines' 'Request Changes  ASP'
#  'Fire Alarm  Replacement' 'Dispatched Taxi Compliment'
#  'Meals Home Delivery Required' 'OEM Disabled Vehicle' 'AdvocateUBT'
#  'AsbestosGarbage Nuisance' 'Trapping Pigeon' 'LEAD' 'MOLD' 'CST'
#  'TrafficIllegal Parking' 'DOF Property  State Rebate' 'SG']
# [nan '11216' '10012' '10456' '10023' '10022' '10036' '10032' '10028'
#  '10304' '10009' '11360' '11205' '11221' '10002' '10010' '11232' '11234'
#  '11362' '10471' '11361' '11363' '10463' '11423' '11367' '10303' '11354'
#  '10308' '11226' '10475' '11224' '11365' '11432' '11233' '10474' '11435'
#  '10454' '10309' '11219' '11102' '10302' '11364' '10461' '10306' '11209'
#  '11433' '10021' '10075' '10128' '11213' '10014' '11356' '10034' '10027'
#  '10031' '11217' '10026' '10452' '11415' '10038' '11434' '11215' '11201'
#  '11427' '10019' '11375' '11218' '11691' '11414' '10307' '10065' '11355'
#  '97005' '32707' '94509' '07880' '33062' '15257' '92807' '15250' '1062'
#  '3337' '02360' '82601' '51564' '60598' '97292' '14305' '1711' '07751'
#  '1066' '06606' '93387' '3370' '20737' '6076' '0886' '60678' '60477'
#  '86303' '53201' '11948' '23608' '30023' '27404' '10560' '75356' '71'
#  '95630' '77034' '11112' '38111' '33445' '18711' '11519' '01650' '45201']

# %% [markdown]
# # What are the number of complaints per department for each zip code?

# %%
# total complaints count
df_count = df_req.groupby(['complaint_type','incident_zip', 'agency']).size(
).reset_index(name="number_of_complaints").sort_values(by='number_of_complaints', ascending=0)
pd.set_option('display.max_rows', 50000)  # or 1000
df_count.head(50)
# Out:
#            complaint_type incident_zip agency  number_of_complaints
# 26005  Noise  Residential        10467   NYPD                 41504
# 26053  Noise  Residential        11226   NYPD                 40430
# 18115       HEATHOT WATER        11226    HPD                 38392
# 26006  Noise  Residential        10468   NYPD                 36095
# 18062       HEATHOT WATER        10458    HPD                 35826
# 18071       HEATHOT WATER        10467    HPD                 34917
# 25996  Noise  Residential        10458   NYPD                 31790
# 18072       HEATHOT WATER        10468    HPD                 31440
# 18057       HEATHOT WATER        10453    HPD                 31389
# 25941  Noise  Residential        10031   NYPD                 31228
# 25994  Noise  Residential        10456   NYPD                 31067
# 25990  Noise  Residential        10452   NYPD                 29958
# 25991  Noise  Residential        10453   NYPD                 29661
# 3572     Blocked Driveway        11368   NYPD                 28389
# 26048  Noise  Residential        11221   NYPD                 28311
# 28570            PLUMBING        11226    HPD                 28303
# 18253             HEATING        10467    HPD                 27963
# 18298             HEATING        11226    HPD                 27255
# 18244             HEATING        10458    HPD                 26508
# 25995  Noise  Residential        10457   NYPD                 26361
# 18056       HEATHOT WATER        10452    HPD                 25877
# 25942  Noise  Residential        10032   NYPD                 25741
# 26033  Noise  Residential        11206   NYPD                 25361
# 26034  Noise  Residential        11207   NYPD                 25310
# 18019       HEATHOT WATER        10031    HPD                 25227
# 18061       HEATHOT WATER        10457    HPD                 24836
# 25950  Noise  Residential        10040   NYPD                 23848
# 18060       HEATHOT WATER        10456    HPD                 23750
# 18254             HEATING        10468    HPD                 23683
# 18239             HEATING        10453    HPD                 23577
# 18066       HEATHOT WATER        10462    HPD                 23545
# 18114       HEATHOT WATER        11225    HPD                 22958
# 25939  Noise  Residential        10029   NYPD                 22923
# 26040  Noise  Residential        11213   NYPD                 22581
# 26039  Noise  Residential        11212   NYPD                 22513
# 21505     Illegal Parking        11385   NYPD                 22342
# 18217             HEATING        10040    HPD                 22264
# 26035  Noise  Residential        11208   NYPD                 22049
# 26052  Noise  Residential        11225   NYPD                 21810
# 18238             HEATING        10452    HPD                 21686
# 26043  Noise  Residential        11216   NYPD                 21320
# 18102       HEATHOT WATER        11213    HPD                 21277
# 25943  Noise  Residential        10033   NYPD                 21262
# 18028       HEATHOT WATER        10040    HPD                 21081
# 25998  Noise  Residential        10460   NYPD                 20972
# 3583     Blocked Driveway        11385   NYPD                 20661
# 25944  Noise  Residential        10034   NYPD                 20512
# 26001  Noise  Residential        10463   NYPD                 20502
# 25937  Noise  Residential        10027   NYPD                 20501
# 26063  Noise  Residential        11237   NYPD                 20426
