# %%
import dask.dataframe as dd
filename = '311_data.csv'
df = dd.read_csv(filename, dtype='str')
df = df.rename(columns={c: c.replace(' ', '') for c in df.columns})

# %%
df.head()
# Out:
#   UniqueKey             CreatedDate              ClosedDate Agency  \
# 0  20122810  03/28/2011 11:20:53 AM  04/13/2011 10:40:27 AM    DOF
# 1  20122811  03/28/2011 11:12:27 PM  03/29/2011 05:07:13 AM   NYPD
# 2  20122812  03/28/2011 04:12:08 PM  03/28/2011 08:03:39 PM    DOF
# 3  20122813  03/28/2011 06:25:54 PM  03/28/2011 07:25:59 PM    DOF
# 4  20122814  03/28/2011 04:16:51 PM  03/28/2011 07:52:23 PM    DOF
#
#                                     AgencyName    ComplaintType  \
# 0  Senior Citizen Rent Increase Exemption Unit            SCRIE
# 1              New York City Police Department  Illegal Parking
# 2  Senior Citizen Rent Increase Exemption Unit            SCRIE
# 3  Senior Citizen Rent Increase Exemption Unit            SCRIE
# 4  Senior Citizen Rent Increase Exemption Unit            SCRIE
#
#                       Descriptor     LocationType IncidentZip  \
# 0               SCRIE Assistance  Address Unknown         NaN
# 1  Posted Parking Sign Violation  Street/Sidewalk       11216
# 2               SCRIE Assistance   Senior Address       10012
# 3               SCRIE Assistance   Senior Address       10456
# 4               SCRIE Assistance   Senior Address       10023
#
#         IncidentAddress  ... VehicleType TaxiCompanyBorough  \
# 0                   NaN  ...         NaN                NaN
# 1  644 LAFAYETTE AVENUE  ...         NaN                NaN
# 2                   NaN  ...         NaN                NaN
# 3                   NaN  ...         NaN                NaN
# 4                   NaN  ...         NaN                NaN
#
#   TaxiPickUpLocation BridgeHighwayName BridgeHighwayDirection RoadRamp  \
# 0                NaN               NaN                    NaN      NaN
# 1                NaN               NaN                    NaN      NaN
# 2                NaN               NaN                    NaN      NaN
# 3                NaN               NaN                    NaN      NaN
# 4                NaN               NaN                    NaN      NaN
#
#   BridgeHighwaySegment           Latitude           Longitude  \
# 0                  NaN                NaN                 NaN
# 1                  NaN  40.69012317171803  -73.94913492072885
# 2                  NaN                NaN                 NaN
# 3                  NaN                NaN                 NaN
# 4                  NaN                NaN                 NaN
#
#                                   Location
# 0                                      NaN
# 1  (40.69012317171803, -73.94913492072885)
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
# [5 rows x 41 columns]

# %%
df.IncidentZip.replace(regex=True,to_replace=r'\D',value=r'')
df.ComplaintType.replace(regex=True,to_replace=r'[^a-zA-Z ]+',value=r'')
# Out:
# Dask Series Structure:
# npartitions=192
#     object
#        ...
#      ...
#        ...
#        ...
# Name: ComplaintType, dtype: object
# Dask Name: replace, 1152 tasks

# %%
import pandas as pd
df_count = df.groupby(['ComplaintType','IncidentZip', 'Agency']).size().reset_index()
pd.set_option('display.max_rows', 50000)  # or 1000
df_count.head(50)
# Out:
#    ComplaintType IncidentZip Agency     0
# 0      APPLIANCE       10001    HPD   113
# 1      APPLIANCE       10002    HPD   527
# 2      APPLIANCE       10003    HPD   357
# 3      APPLIANCE       10009    HPD   485
# 4      APPLIANCE       10011    HPD   325
# 5      APPLIANCE       10013    HPD   127
# 6      APPLIANCE       10014    HPD   206
# 7      APPLIANCE       10016    HPD   312
# 8      APPLIANCE       10019    HPD   367
# 9      APPLIANCE       10023    HPD   203
# 10     APPLIANCE       10024    HPD   361
# 11     APPLIANCE       10025    HPD   860
# 12     APPLIANCE       10026    HPD   814
# 13     APPLIANCE       10027    HPD  1289
# 14     APPLIANCE       10028    HPD   303
# 15     APPLIANCE       10029    HPD  1033
# 16     APPLIANCE       10030    HPD   921
# 17     APPLIANCE       10031    HPD  2073
# 18     APPLIANCE       10032    HPD  1925
# 19     APPLIANCE       10033    HPD  1279
# 20     APPLIANCE       10034    HPD  1181
# 21     APPLIANCE       10035    HPD   891
# 22     APPLIANCE       10036    HPD   327
# 23     APPLIANCE       10037    HPD   519
# 24     APPLIANCE       10039    HPD   705
# 25     APPLIANCE       10040    HPD  1086
# 26     APPLIANCE       10128    HPD   257
# 27     APPLIANCE       10301    HPD   568
# 28     APPLIANCE       10302    HPD   262
# 29     APPLIANCE       10303    HPD   261
# 30     APPLIANCE       10304    HPD   717
# 31     APPLIANCE       10310    HPD   276
# 32     APPLIANCE       10314    HPD   164
# 33     APPLIANCE       10451    HPD  1157
# 34     APPLIANCE       10452    HPD  3044
# 35     APPLIANCE       10453    HPD  3598
# 36     APPLIANCE       10454    HPD   823
# 37     APPLIANCE       10455    HPD  1069
# 38     APPLIANCE       10456    HPD  3192
# 39     APPLIANCE       10457    HPD  3212
# 40     APPLIANCE       10458    HPD  3282
# 41     APPLIANCE       10459    HPD  1570
# 42     APPLIANCE       10460    HPD  1976
# 43     APPLIANCE       10461    HPD   558
# 44     APPLIANCE       10462    HPD  1298
# 45     APPLIANCE       10463    HPD  1186
# 46     APPLIANCE       10464    HPD    18
# 47     APPLIANCE       10465    HPD   152
# 48     APPLIANCE       10466    HPD  1666
# 49     APPLIANCE       10467    HPD  3150
